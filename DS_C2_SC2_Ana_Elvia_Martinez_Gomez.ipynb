# %% [markdown]
# #a. Extraer la información del archivo.

# %%
import pandas as pd

df=pd.read_csv("/content/country_vaccinations.csv")
df.head(2)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/

# %% [markdown]
# b. Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurándote que las columnas con fechas sean del tipo datetime64.

# %%
df['date'] = pd.to_datetime(df['date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  datetime64[ns]
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
#  11  daily_vaccinations_per_million       86213 non-null  float64
#  12  vaccines                             86512 non-null  object
#  13  source_name                          86512 non-null  object
#  14  source_website                       86512 non-null  object
# dtypes: datetime64[ns](1), float64(9), object(5)
# memory usage: 9.9+ MB

# %% [markdown]
# c. Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna vaccines, en otras palabras, agrupe por vaccines y realice la sumatoria).

# %%
df[["vaccines", "daily_vaccinations"]].groupby("vaccines").sum()
# Out:
#                                                     daily_vaccinations
# vaccines
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pf...           9616160.0
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/Bio...         201816053.0
# Abdala, Sinopharm/Beijing, Sinovac, Soberana02,...          37861146.0
# Abdala, Soberana Plus, Soberana02                           33802957.0
# COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/Ast...         146357015.0
# ...                                                                ...
# Pfizer/BioNTech, Sinovac, Turkovac                         147484328.0
# Pfizer/BioNTech, Sputnik V                                     68643.0
# QazVac, Sinopharm/Beijing, Sputnik V                        20891256.0
# Sinopharm/Beijing                                             893824.0
# Sinopharm/Beijing, Sputnik V                                14398697.0
#
# [84 rows x 1 columns]

# %% [markdown]
# d. Obtener la cantidad de vacunas aplicadas en todo el mundo.

# %%
df["daily_vaccinations"].sum()
# Out:
# np.float64(11320239871.0)

# %% [markdown]
# e. Calcular el promedio de vacunas aplicadas por país.

# %%
df[["country", "daily_vaccinations"]].groupby("country").mean()
# Out:
#                    daily_vaccinations
# country
# Afghanistan              14610.681934
# Albania                   6276.210046
# Algeria                  33904.356436
# Andorra                    367.716019
# Angola                   44821.457584
# ...                               ...
# Wales                    15518.411765
# Wallis and Futuna           33.886486
# Yemen                     2556.115756
# Zambia                    9649.805158
# Zimbabwe                 21669.066832
#
# [223 rows x 1 columns]

# %% [markdown]
# f. Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo.

# %%
total_vacunas_29_01_21 = df.loc[df["date"] == "2021-01-29", "daily_vaccinations"].sum()
print(f"Total de vacunas aplicadas el día 29/01/21 es: {total_vacunas_29_01_21}")
# Out:
# Total de vacunas aplicadas el día 29/01/21 es: 4884052.0

# %% [markdown]
# g. Crear un dataframe nuevo denominado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw

# %%
conDiferencias=df.copy()
conDiferencias["diferencias"]=conDiferencias["daily_vaccinations"]-conDiferencias["daily_vaccinations_raw"]
conDiferencias.tail()
# Out:
#         country iso_code       date  total_vaccinations  people_vaccinated  \
# 86507  Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508  Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509  Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510  Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511  Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 86507                3473523.0                139213.0             69579.0
# 86508                3487962.0                100086.0             83429.0
# 86509                3493763.0                 53311.0             90629.0
# 86510                3501493.0                 89321.0            100614.0
# 86511                3510256.0                105369.0            103751.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 86507                           57.59                          31.90
# 86508                           58.25                          32.38
# 86509                           58.61                          32.59
# 86510                           59.20                          32.97
# 86511                           59.90                          33.48
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 86507                                23.02                          4610.0
# 86508                                23.11                          5528.0
# 86509                                23.15                          6005.0
# 86510                                23.20                          6667.0
# 86511                                23.26                          6874.0
#
#                                                 vaccines         source_name  \
# 86507  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 86508  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 86509  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 86510  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 86511  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
#
#                                           source_website  diferencias
# 86507  https://www.arcgis.com/home/webmap/viewer.html...     -69634.0
# 86508  https://www.arcgis.com/home/webmap/viewer.html...     -16657.0
# 86509  https://www.arcgis.com/home/webmap/viewer.html...      37318.0
# 86510  https://www.arcgis.com/home/webmap/viewer.html...      11293.0
# 86511  https://www.arcgis.com/home/webmap/viewer.html...      -1618.0

# %% [markdown]
# h. Obtener el periodo de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua.

# %%
print("Fecha más reciente:", df["date"].max())
print("Fecha más antigua:", df["date"].min())
# Out:
# Fecha más reciente: 2022-03-29 00:00:00
# Fecha más antigua: 2020-12-02 00:00:00

# %% [markdown]
# i. Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter , ).

# %%
conCantidad=df.copy()
conCantidad["canVac"]=conCantidad["vaccines"].str.split(",").str.len()
conCantidad[["canVac","vaccines"]].head(5)
# Out:
#    canVac                                           vaccines
# 0       4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1       4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2       4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3       4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4       4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...

# %% [markdown]
# j. Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.

# %%
antes20=df.copy()
antes20=antes20[antes20["date"]<"2020-12-20"]

# %%
print("Fecha más reciente:", antes20["date"].max())
# Out:
# Fecha más reciente: 2020-12-19 00:00:00

# %% [markdown]
# k. Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer.

# %%
pfizer=df.copy()
pfizer=pfizer[pfizer["vaccines"].str.contains("Pfizer")]
pfizer.tail(2)
# Out:
#       country  iso_code       date  total_vaccinations  people_vaccinated  \
# 85072   Wales  OWID_WLS 2022-03-27           6925183.0          2528051.0
# 85073   Wales  OWID_WLS 2022-03-28           6927437.0          2528664.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 85072                2398676.0                  1477.0              1505.0
# 85073                2399341.0                  2254.0              1609.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 85072                          218.46                          79.75
# 85073                          218.53                          79.77
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 85072                                75.67                           475.0
# 85073                                75.69                           508.0
#
#                                            vaccines  \
# 85072  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 85073  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
#
#                             source_name  \
# 85072  Government of the United Kingdom
# 85073  Government of the United Kingdom
#
#                                           source_website
# 85072  https://coronavirus.data.gov.uk/details/vaccin...
# 85073  https://coronavirus.data.gov.uk/details/vaccin...

# %%
#!pip install xlsxwriter

# %% [markdown]
# l. Almacenar los dataframes generados (conDiferencias, conCantidad, antes20 y pfizer) en un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter.

# %%
with pd.ExcelWriter("resultadosReto.xlsx", engine="xlsxwriter") as writer:
    conDiferencias.to_excel(writer, sheet_name="ConDiferencias", index=False)
    conCantidad.to_excel(writer, sheet_name="ConCantidad", index=False)
    antes20.to_excel(writer, sheet_name="Antes20", index=False)
    pfizer.to_excel(writer, sheet_name="Pfizer", index=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://ais.paho.org/imm/IM_DosisAdmin-Vacunacion.asp' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://web.facebook.com/SVGHEALTH/posts/437021804887233' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://stats.pacificdata.org/vis?tm=covid&pg=0&df[ds]=SPC2&df[id]=DF_COVID_VACCINATION&df[ag]=SPC&df[vs]=1.0' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://covid19.who.int/' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://africacdc.org/covid-19-vaccination/' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://coronavirus.data.gov.uk/details/vaccinations' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://vakcinacija.gov.rs/' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://data.gov.sg/dataset/covid-19-vaccination' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://github.com/Institut-Zdravotnych-Analyz/covid19-data/raw/main/Vaccination/OpenData_Slovakia_Vaccination_AgeGroup_District.csv' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://covid-19.sledilnik.org/sl/stats' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://sacoronavirus.co.za/latest-vaccine-statistics/' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://ncv.kdca.go.kr/' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov/documentos/Informe_Comunicacion_20220325.ods' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://www.epid.gov.lk/web/images/pdf/corona_vaccination/covid_vaccination_2022-03_22.pdf' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://laatjevaccineren.sr/' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://fohm.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/statistik-och-analyser/statistik-over-registrerade-vaccinationer-covid-19/' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://opendata.swiss/en/dataset/covid-19-schweiz?detGeo=CH' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://www.cdc.gov.tw/Category/Page/9jFXNbCe-sFK9EImRRi2Og' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://ddc.moph.go.th/covid19-dashboard/' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://services3.arcgis.com/x3I4DqUw3b3MfTwQ/arcgis/rest/services/service_7a519502598f492a9094fd0ad503cf80/FeatureServer/0/query' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://web.facebook.com/santetunisie.rns.tn/posts/339797681524034?__cft__[0]=AZUiZe_DZCgQaUfW53dSTtXxKD5Vmq3M4OkNzKUMnMjzyKYqwPgH6EV-do3PCuT4TqokRZFYjLLshZ87APo1I0dbZHgTHn-95N8CB7Crpo5q1AShf3f9AQYWATKZCptNluocUhFJ8tKk3Z4cIg3qRVhQ&__tn__=%2CO%2CP-R' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://covid19asi.saglik.gov.tr/' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://health-security.rnbo.gov.ua' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://fcsc.gov.ae/en-us/Pages/Covid19/UAE-Covid-19-Updates.aspx' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://data.cdc.gov/Vaccinations/COVID-19-Vaccination-Trends-in-the-United-States-N/rh2h-3yt2' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://monitor.uruguaysevacuna.gub.uy/' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://covid19.gov.vn/ngay-23-3-so-mac-moi-covid-19-giam-con-127883-ca-tuyen-quang-bo-sung-gan-13000-f0-171220323181603013.htm' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://rtc-planning.maps.arcgis.com/apps/dashboards/3b3a01c1d8444932ba075fb44b119b63' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /usr/local/lib/python3.12/dist-packages/xlsxwriter/worksheet.py:1321: UserWarning: Ignoring URL 'https://www.arcgis.com/home/webmap/viewer.html?url=https://services9.arcgis.com/DnERH4rcjw7NU6lv/ArcGIS/rest/services/Vaccine_Distribution_Program/FeatureServer&source=sd' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
